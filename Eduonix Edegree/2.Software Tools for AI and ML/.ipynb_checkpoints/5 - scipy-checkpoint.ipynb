# %%
### Useful scipy functions
# https://docs.scipy.org/doc/scipy/reference/stats.html
# T-tests
from scipy import stats
from sklearn import datasets
import pandas as pd

iris = datasets.load_iris()
x = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.DataFrame(iris.target, columns = ["species"],dtype='category')

# stats.ttest_ind(x["sepal length (cm)"],x["petal length (cm)"])

# stats.shapiro(x["sepal length (cm)"])
# stats.bartlett(x["sepal length (cm)"], x["sepal width (cm)"])

# stats.zscore(x["sepal length (cm)"])

# stats.linregress(x["sepal length (cm)"],x["petal length (cm)"])
stats.chisquare(x["sepal length (cm)"],x["petal length (cm)"])
# Out:
# Power_divergenceResult(statistic=486.8784192231252, pvalue=1.7628224168601675e-37)

# %%
### Audio signal processing
# https://docs.scipy.org/doc/scipy-1.2.1/reference/generated/scipy.signal.spectrogram.html
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from scipy.io import wavfile

fs = 44100 # Sampling frequency (10000 per second)
N = 100000 # Number of samples
frequency = 3000 # Soundwave frequency (Hertz)
time = np.arange(N) / float(fs) # Time in seconds

amp = 2 * np.sqrt(2)
mod = 500*np.cos(2*np.pi*0.5*time)

sigMod = amp * np.sin(2*np.pi*frequency*time)
nse = 0.01 * np.random.random(size=len(time))

x = sigMod # * nse
# s = np.sin(2 * np.pi * 1700 * time)

# f, t, Sxx = signal.spectrogram(x, fs)
# plt.pcolormesh(t, f, Sxx)
# plt.ylabel('Frequency [Hz]')
# plt.xlabel('Time [sec]')
# plt.show()


# https://www.cs.tut.fi/sgn/arg/intro/basics/pia60.wav
sample_rate, samples = wavfile.read('/Users/arayi/Downloads/pia60.wav')
frequencies, times, spectrogram = signal.spectrogram(samples, sample_rate)

plt.pcolormesh(times, frequencies, np.log(spectrogram))
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
### Image signal processing
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.ndimage.fourier_gaussian.html#scipy.ndimage.fourier_gaussian
from scipy import ndimage, misc
import numpy.fft
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm


ascent = misc.ascent()
# ascent
# plt.imshow(ascent)
# plt.gray()
# plt.show()

# input_ = numpy.fft.fft2(ascent)
# input_

plt.figure()
plt.imshow(np.abs(input_),norm=LogNorm(vmin=5))
plt.colorbar()
plt.title('Fourier transform')
plt.show()


result = ndimage.fourier_gaussian(input_, sigma=5)
result = numpy.fft.ifft2(result)
# result
# plt.figure()
# plt.imshow(np.abs(result),norm=LogNorm(vmin=5))
# plt.title('Fourier transform')
# plt.show()

# %%
# Problem Section

from matplotlib import pyplot as plt
import cv2

image_data = cv2.imread('5.jpg')

scaled_image_data = image_data / 255.
scaled_image_data.shape

image_slice_red =  scaled_image_data[:,:,0]
image_slice_green =  scaled_image_data[:,:,1]
image_slice_blue =  scaled_image_data[:,:,2]

plt.subplot(221)
plt.imshow(image_slice_red, cmap=plt.cm.Reds_r)
plt.subplot(222)
plt.imshow(image_slice_green, cmap=plt.cm.Greens_r)
plt.subplot(223)
plt.imshow(image_slice_blue, cmap=plt.cm.Blues_r)  
plt.subplot(224)
plt.imshow(image_data)  
plt.show()

# image_data
