# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()
# train_images.shape
# print(train_labels)

train_images = train_images / 255.0
test_images = test_images / 255.0
labelNames = ["top", "trouser", "pullover", "dress", "coat", "sandal", "shirt", "sneaker", "bag", "ankle boot"]


model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(optimizer='Adadelta',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

model_log=model.fit(train_images, train_labels, epochs=15, validation_data=(test_images, test_labels))
fig = plt.figure()
plt.subplot(2,1,1)
plt.plot(model_log.history['acc'])
plt.plot(model_log.history['val_acc'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(model_log.history['loss'])
plt.plot(model_log.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.tight_layout()
#fig
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/15
# 60000/60000 [==============================] - 10s 164us/sample - loss: 0.5107 - acc: 0.8171 - val_loss: 0.4353 - val_acc: 0.8451
# Epoch 2/15
# 60000/60000 [==============================] - 9s 158us/sample - loss: 0.3766 - acc: 0.8630 - val_loss: 0.4206 - val_acc: 0.8424
# Epoch 3/15
# 60000/60000 [==============================] - 9s 157us/sample - loss: 0.3403 - acc: 0.8763 - val_loss: 0.3773 - val_acc: 0.8672
# Epoch 4/15
# 60000/60000 [==============================] - 9s 154us/sample - loss: 0.3158 - acc: 0.8841 - val_loss: 0.3655 - val_acc: 0.8669
# Epoch 5/15
# 60000/60000 [==============================] - 9s 158us/sample - loss: 0.2999 - acc: 0.8910 - val_loss: 0.3516 - val_acc: 0.8765
# Epoch 6/15
# 60000/60000 [==============================] - 9s 154us/sample - loss: 0.2866 - acc: 0.8954 - val_loss: 0.3550 - val_acc: 0.8759
# Epoch 7/15
# 60000/60000 [==============================] - 10s 160us/sample - loss: 0.2767 - acc: 0.8996 - val_loss: 0.3375 - val_acc: 0.8832
# Epoch 8/15
# 60000/60000 [==============================] - 10s 159us/sample - loss: 0.2669 - acc: 0.9031 - val_loss: 0.3552 - val_acc: 0.8781
# Epoch 9/15
# 60000/60000 [==============================] - 10s 160us/sample - loss: 0.2573 - acc: 0.9047 - val_loss: 0.3410 - val_acc: 0.8838
# Epoch 10/15
# 60000/60000 [==============================] - 9s 158us/sample - loss: 0.2499 - acc: 0.9092 - val_loss: 0.3467 - val_acc: 0.8792
# Epoch 11/15
# 60000/60000 [==============================] - 9s 156us/sample - loss: 0.2426 - acc: 0.9119 - val_loss: 0.3613 - val_acc: 0.8787
# Epoch 12/15
# 60000/60000 [==============================] - 10s 161us/sample - loss: 0.2340 - acc: 0.9148 - val_loss: 0.3384 - val_acc: 0.8845
# Epoch 13/15
# 60000/60000 [==============================] - 10s 165us/sample - loss: 0.2295 - acc: 0.9158 - val_loss: 0.3744 - val_acc: 0.8772
# Epoch 14/15
# 60000/60000 [==============================] - 10s 165us/sample - loss: 0.2232 - acc: 0.9186 - val_loss: 0.3761 - val_acc: 0.8759
# Epoch 15/15
# 60000/60000 [==============================] - 14s 235us/sample - loss: 0.2204 - acc: 0.9199 - val_loss: 0.3634 - val_acc: 0.8825
