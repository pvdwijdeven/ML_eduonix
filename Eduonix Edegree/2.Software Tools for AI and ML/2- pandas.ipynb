# %%
# LOADING AND MANIPULATING PANDAS
# https://pandas.pydata.org/
# 2.1

import pandas as pd
from sklearn import datasets

# pd.read_csv("path/to/file.csv", delimiter="\t",header=None)
# iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
# iris
# iris2 = datasets.load_iris()
# iris2

iris.describe()
# iris.groupby("species").describe()
# iris.mean()
# iris['sepal_length'].median()
# iris.petal_length
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# INDEXING
# 2.2
# iris[1:3][['petal_length','petal_width']]
# iris[['petal_length','petal_width']]

# iris.iloc[3:4,1:3]

iris[(iris.petal_length > 5) & (iris.petal_width < 2)]


# iris.loc[iris['column_name'] == some_value
iris.loc[iris['petal_length'].isin([4.3,5.2])]
# ~
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 74            6.4          2.9           4.3          1.3  versicolor
# 97            6.2          2.9           4.3          1.3  versicolor
# 145           6.7          3.0           5.2          2.3   virginica
# 147           6.5          3.0           5.2          2.0   virginica

# %%
# EXAMINING REAL DATA
# SIMPLE PLOTTING
# 2.3
# http://archive.ics.uci.edu/ml/datasets/Occupancy+Detection+
import pandas as pd

occu = pd.read_csv("datatest.txt")
# occu.head()
# occu.dtypes
# occu.describe()
# occu.groupby("Occupancy").describe()

# occu["Light"][:100].plot(kind='line')
occu.set_index("date")["Light"][:100].plot(kind='line')

# %%
# USEFUL FUNCTIONS
# 2.4

iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# iris.iloc[ROW_INDEX,COLUMN_INDEX]


# iris.iterrows():

# iris.iterrows()
# for row, value in iris.iterrows():
#     if sum(value[:4]) > 5:
#         iris.iloc[row,4] = "New"
# iris.head()

# iris.replace("New","lily")

X = iris[["sepal_length","petal_width"]]

# iris.dtypes
# iris["species"] = iris["species"].astype('category')
# iris["species"] = iris["species"].cat.codes

# iris
# y

# %%
 ## Learn pct.change, and apply some processing to data for final or problem section
# Google how to create a dataframe and input information for sklearn iris data
# Replace species name in iris with integer
from sklearn import datasets
iris = datasets.load_iris()

data = iris['data']
col = iris['feature_names']

df = pd.DataFrame(data,columns=col)
df['species'] = iris['target']


# Find the percentage change using a 5 period moving window for the Occupancy dataset 
occu = pd.read_csv("~/Downloads/occupancy_data/datatest.txt")
occuTempPct = occu["Temperature"].pct_change(periods=5)
occuTempPct
